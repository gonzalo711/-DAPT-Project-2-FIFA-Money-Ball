# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('Fifa 23 Players Data.csv')

# %%
data.head()
# Out:
#          Known As           Full Name  Overall  Potential  Value(in Euro)  \
# 0        L. Messi        Lionel Messi       91         91        54000000
# 1      K. Benzema       Karim Benzema       91         91        64000000
# 2  R. Lewandowski  Robert Lewandowski       91         91        84000000
# 3    K. De Bruyne     Kevin De Bruyne       91         91       107500000
# 4       K. Mbappé       Kylian Mbappé       91         95       190500000
#
#   Positions Played Best Position Nationality  \
# 0               RW           CAM   Argentina
# 1            CF,ST            CF      France
# 2               ST            ST      Poland
# 3           CM,CAM            CM     Belgium
# 4            ST,LW            ST      France
#
#                                          Image Link  Age  ...  LM Rating  \
# 0  https://cdn.sofifa.net/players/158/023/23_60.png   35  ...         91
# 1  https://cdn.sofifa.net/players/165/153/23_60.png   34  ...         89
# ...

# %%
display(data)
# Out:
#              Known As           Full Name  Overall  Potential  Value(in Euro)  \
# 0            L. Messi        Lionel Messi       91         91        54000000
# 1          K. Benzema       Karim Benzema       91         91        64000000
# 2      R. Lewandowski  Robert Lewandowski       91         91        84000000
# 3        K. De Bruyne     Kevin De Bruyne       91         91       107500000
# 4           K. Mbappé       Kylian Mbappé       91         95       190500000
# ...               ...                 ...      ...        ...             ...
# 18534      D. Collins      Darren Collins       47         56          110000
# 18535    Yang Dejiang        Dejiang Yang       47         57           90000
# 18536       L. Mullan         Liam Mullan       47         67          130000
# 18537    D. McCallion    Daithí McCallion       47         61          100000
# 18538        N. Rabha         Nabin Rabha       47         50           60000
#
# ...

# %%
#Check the names of the columns
data.columns
# Out:
# Index(['Known As', 'Full Name', 'Overall', 'Potential', 'Value(in Euro)',
#        'Positions Played', 'Best Position', 'Nationality', 'Image Link', 'Age',
#        'Height(in cm)', 'Weight(in kg)', 'TotalStats', 'BaseStats',
#        'Club Name', 'Wage(in Euro)', 'Release Clause', 'Club Position',
#        'Contract Until', 'Club Jersey Number', 'Joined On', 'On Loan',
#        'Preferred Foot', 'Weak Foot Rating', 'Skill Moves',
#        'International Reputation', 'National Team Name',
#        'National Team Image Link', 'National Team Position',
#        'National Team Jersey Number', 'Attacking Work Rate',
#        'Defensive Work Rate', 'Pace Total', 'Shooting Total', 'Passing Total',
#        'Dribbling Total', 'Defending Total', 'Physicality Total', 'Crossing',
#        'Finishing', 'Heading Accuracy', 'Short Passing', 'Volleys',
#        'Dribbling', 'Curve', 'Freekick Accuracy', 'LongPassing', 'BallControl',
# ...

# %%
#Review 'TotalStats', 'BaseStats' columns -how is it calculated?
data[['TotalStats','BaseStats']]
# Out:
#        TotalStats  BaseStats
# 0            2190        452
# 1            2147        455
# 2            2205        458
# 3            2303        483
# 4            2177        470
# ...           ...        ...
# 18534        1287        274
# 18535        1289        267
# 18536        1333        277
# 18537        1113        226
# 18538        1277        269
#
# [18539 rows x 2 columns]

# %%
#Filter our players
manchester_clubs = data[data['Club Name'].str.contains("Manchester")]
manchester_clubs

data.loc[3]['Club Name']
# Out:
# 'Manchester City'

# %%
man_city_players = data[data['Club Name'] == 'Manchester City']

# Create our team dataframe
team = man_city_players.copy()
display(team)

team.describe()
# Out:
#                 Known As                       Full Name  Overall  Potential  \
# 3           K. De Bruyne                 Kevin De Bruyne       91         91
# 16               Ederson       Ederson Santana de Moraes       89         91
# 20            Rúben Dias    Rúben Santos Gato Alves Dias       88         91
# 21            E. Haaland                  Erling Haaland       88         94
# 23        Bernardo Silva  Bernardo Mota Carvalho e Silva       88         88
# 24          João Cancelo       João Pedro Cavaco Cancelo       88         88
# 31                 Rodri      Rodrigo Hernández Cascante       87         89
# 48             R. Mahrez                    Riyad Mahrez       86         86
# 55            A. Laporte                 Aymeric Laporte       86         87
# 68           İ. Gündoğan                  İlkay Gündoğan       85         85
# 69             K. Walker                     Kyle Walker       85         85
# ...

# %%
#What our budget
budget=team['Wage(in Euro)'].sum()
print(budget)
# Out:
# 3669650

# %%
"""ST Rating: Striker Rating - This represents a player's ability as a forward, the primary goal scorer of the team.

LW Rating: Left Wing Rating - Indicates the player's skill when playing on the left wing, typically a position known for speed and crossing ability.

LF Rating: Left Forward Rating - Similar to the LW position, it's typically an attacking role on the left side of the field.

CF Rating: Center Forward Rating - Refers to a player who operates centrally in the attacking area, often as the main striker or a playmaking forward.

RF Rating: Right Forward Rating - Similar to the LF position, but on the right side of the field.

RW Rating: Right Wing Rating - Represents a player's ability when playing on the right wing.

CAM Rating: Central Attacking Midfielder Rating - This is an attacking midfield role that focuses on creating goal-scoring opportunities.

LM Rating: Left Midfielder Rating - Indicates the player's skills when playing as a left-sided midfielder.

CM Rating: Central Midfielder Rating - Represents the player's ability in a central midfield role, which often involves both defensive and offensive duties.

RM Rating: Right Midfielder Rating - Reflects a player's ability when playing as a right-sided midfielder.

LWB Rating: Left Wing Back Rating - This is a player's ability when deployed as a wing-back on the left side, often involved in both defending and attacking.

CDM Rating: Central Defensive Midfielder Rating - This role is primarily focused on defensive duties, protecting the backline, and distributing the ball from deep positions.

RWB Rating: Right Wing Back Rating - Similar to LWB, but on the right side, often used in systems that employ wing-backs.

LB Rating: Left Back Rating - Represents a player's ability when playing as a left-back, a position focused on defensive and supporting the attack.

CB Rating: Center Back Rating - Indicates a player's skill as a central defender, responsible for stopping the opposition's attacks.

RB Rating: Right Back Rating - Reflects a player's ability as a right-back, which is a defensive and supporting role on the right side.

GK Rating: Goalkeeper Rating - This represents the skills and attributes of a team's goalkeeper, responsible for stopping shots and organizing the defense."""
